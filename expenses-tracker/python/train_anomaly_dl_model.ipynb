# %%
import pandas as pd
import numpy as np
import joblib
import os
import json
from sklearn.preprocessing import StandardScaler
import keras
from keras import layers

def build_autoencoder(input_dim):
    model = keras.Sequential([
        layers.Dense(8, activation='relu', input_shape=(input_dim,)),
        layers.Dense(4, activation='relu'),
        layers.Dense(2, activation='relu'), 
        layers.Dense(4, activation='relu'),
        layers.Dense(8, activation='relu'),
        layers.Dense(input_dim, activation='linear')
    ])
    model.compile(optimizer='adam', loss='mse')
    return model
# Out:
# c:\Users\BIMSARA\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
def train_anomaly_dl(mode='expense'):
    dataset_path = 'personal_finance_tracker_dataset.csv'
    if not os.path.exists(dataset_path):
        print("Dataset not found!")
        return
        
    df = pd.read_csv(dataset_path)
    col_cat = 'category' if mode == 'expense' else 'income_type'
    col_amt = 'monthly_expense_total' if mode == 'expense' else 'monthly_income'
    
    # 1. Prepare Data
    X_raw = df[[col_cat, col_amt]].copy()
    unique_cats = X_raw[col_cat].unique().tolist()
    cat_to_id = {cat: i for i, cat in enumerate(unique_cats)}
    X_raw['cat_label'] = X_raw[col_cat].map(cat_to_id)
    
    X = X_raw[['cat_label', col_amt]].values
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # 2. Train
    model = build_autoencoder(X_scaled.shape[1])
    model.fit(X_scaled, X_scaled, epochs=50, batch_size=32, verbose=1)
    
    # 3. Save
    model.save(f'dl_anomaly_{mode}_model.keras')
    joblib.dump(scaler, f'scaler_anomaly_{mode}.pkl')
    
    # Save threshold
    reconstructions = model.predict(X_scaled)
    mse = np.mean(np.power(X_scaled - reconstructions, 2), axis=1)
    threshold = np.percentile(mse, 99.5)
    with open(f'threshold_{mode}.json', 'w') as f:
        json.dump({"threshold": float(threshold)}, f)
        
    print(f"{mode.upper()} training complete. Threshold: {threshold}")

train_anomaly_dl('expense')
train_anomaly_dl('income')
# Out:
# c:\Users\BIMSARA\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.9020
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7071
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6267
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5844
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5560
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5381
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5259
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5184
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5133
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5100
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5076
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5058
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5044
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5036
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5031
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5026
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5021
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5025
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5025
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5024
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5016
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5013
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5025
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5014
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5014
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5013
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5011
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5009
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5012
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5014
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5013
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5010
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5015
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5010
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5011
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5010
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5007
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5011
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5008
# Epoch 40/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5008
# Epoch 41/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5022
# Epoch 42/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5008
# Epoch 43/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5008
# Epoch 44/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5010
# Epoch 45/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5009
# Epoch 46/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5014
# Epoch 47/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5015
# Epoch 48/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5009
# Epoch 49/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5007
# Epoch 50/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5012
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# EXPENSE training complete. Threshold: 1.895919861966446
# Epoch 1/50
# c:\Users\BIMSARA\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.8268
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6732
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6151
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5212
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2506
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0870
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0588
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0434
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0333
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0261
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0208
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0134
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0108
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0087
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0070
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0026
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0022
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0016
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2322e-04
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2321e-04
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9459e-04
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1738e-04
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7692e-04
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4775e-04
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8391e-04
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3860e-04
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5247e-04
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5677e-04
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8864e-04
# Epoch 40/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1963e-04
# Epoch 41/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6605e-04
# Epoch 42/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8323e-04
# Epoch 43/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5465e-04
# Epoch 44/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2606e-04
# Epoch 45/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9974e-04
# Epoch 46/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8605e-04
# Epoch 47/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6366e-04
# Epoch 48/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7831e-04
# Epoch 49/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6199e-04
# Epoch 50/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4597e-04
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# INCOME training complete. Threshold: 0.003973129368799577

# %%
import json, joblib, numpy as np, pandas as pd, tensorflow as tf
from sklearn.preprocessing import StandardScaler

mode = 'income'   # or 'income'

df = pd.read_csv('personal_finance_tracker_dataset.csv')

col_cat = 'category' if mode == 'expense' else 'income_type'
col_amt = 'monthly_expense_total' if mode == 'expense' else 'monthly_income'

X_raw = df[[col_cat, col_amt]].copy()

# recreate category mapping (must match training)
unique_cats = X_raw[col_cat].unique().tolist()
cat_to_id = {cat: i for i, cat in enumerate(unique_cats)}
X_raw['cat_label'] = X_raw[col_cat].map(cat_to_id)

X = X_raw[['cat_label', col_amt]].values

scaler = joblib.load(f'scaler_anomaly_{mode}.pkl')
X_scaled = scaler.transform(X)

model = tf.keras.models.load_model(f'dl_anomaly_{mode}_model.keras')

with open(f'threshold_{mode}.json') as f:
    threshold = json.load(f)['threshold']

# %%
reconstructions = model.predict(X_scaled)
mse = np.mean(np.power(X_scaled - reconstructions, 2), axis=1)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
anomalies = mse > threshold
print(f"{mode.upper()} anomaly %:", anomalies.mean() * 100)
print("Total anomalies:", anomalies.sum())
# Out:
# INCOME anomaly %: 0.5
# Total anomalies: 15
